# %%
import asyncio
from telethon import TelegramClient
import pickle
import re
from nltk.stem import PorterStemmer
import nltk
from sklearn.feature_extraction.text import TfidfVectorizer

# Download NLTK resources if not already installed
nltk.download('punkt')

# TELEGRAM API CREDENTIALS

api_id = ''
api_hash = ''
channel_username = ''  # e.g., '@example_channel'

# Initialize Porter Stemmer
stemmer = PorterStemmer()

# Function to scrape Telegram messages (asynchronous)
async def scrape_telegram_messages():
    async with TelegramClient('session_name', api_id, api_hash) as client:

        messages = await client.get_messages(channel_username, limit=100)  # Fetch last 100 messages
        return [msg.message for msg in messages if msg.message]

# TEXT PREPROCESSING WITH STEMMING
def preprocess_text(text):
    # Basic cleaning
    text = re.sub(r'http\S+', '', text)  # Remove URLs
    text = re.sub(r'@\w+', '', text)    # Remove mentions
    text = re.sub(r'#\w+', '', text)    # Remove hashtags
    text = re.sub(r'[^\w\s]', '', text) # Remove punctuation
    text = text.lower().strip()         # Convert to lowercase and strip whitespace

    # Tokenization and stemming
    tokens = text.split()  # Split text into words
    stemmed_tokens = [stemmer.stem(word) for word in tokens]  # Apply stemming
    return ' '.join(stemmed_tokens)  # Join back into a single string

# LOAD MODEL
def load_model(model_path):
    with open(model_path, 'rb') as model_file:
        model = pickle.load(model_file)
    return model

# FAKE NEWS DETECTION
def detect_fake_news(messages, model):
    # Preprocess messages and apply stemming
    cleaned_data = [preprocess_text(msg) for msg in messages]

    # Initialize a new vectorizer (fit it on your messages)
    vectorizer = TfidfVectorizer(max_features=5000, ngram_range=(1, 3), min_df=1)
    features = vectorizer.fit_transform(cleaned_data)  # Fit and transform the text

    # Make predictions
    predictions = model.predict(features)
    return [{"message": msg, "is_fake": bool(pred)} for msg, pred in zip(messages, predictions)]

# MAIN EXECUTION
async def main():
    # Path to your pickle file
    model_path = 'fakenewsmodel.pkl'

    # Load model
    print("Loading model...")
    model = load_model(model_path)

    # Scrape Telegram messages
    print("Scraping messages from Telegram channel...")
    scraped_messages = await scrape_telegram_messages()

    if not scraped_messages:
        print("No messages found!")
    else:
        # Detect fake news
        print("Detecting fake news...")
        results = detect_fake_news(scraped_messages, model)

        # Display results
        for result in results:
            print(f"Message: {result['message']}\nFake News: {result['is_fake']}\n")

# Run the asynchronous main function (for Jupyter Notebooks)
if __name__ == "__main__":
    await main()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Loading model...
# Scraping messages from Telegram channel...
# Please enter your phone (or bot token): +917997084098
# Please enter the code you received: 78599
# Signed in successfully as Sai Rohan; remember to not break the ToS or you will risk an account ban!
# Detecting fake news...
# Message: President Biden calls for ban on congressional stock trading.
#
# "Nobody in the Congress should be able to make money in the stock market while they're in the Congress."
#
# 🔵Powered by V3V Ventures
# Fake News: False
#
# Message: China executes official in $412 million corruption case.
#
# China on Tuesday executed a 64-year-old former official who was convicted of bribery, state media reported.
#
# Li Jianping, who served in the northern Inner Mongolia autonomous region, was convicted of corruption, bribery, misappropriation of public funds, and collusion with a criminal syndicate.
#
# The 64-year-old official was given a death sentence in September 2022, which was upheld in August this year.
#
# 🔵Powered by V3V Ventures
# Fake News: False
#
# Message: Apple is 5% away from hitting a $4 trillion market cap.
#
# 🔵Powered by V3V Ventures
# Fake News: False
#
# Message: Ethereum Foundation just sold 100 $ETH and has now sold a total of over $12.5 million worth this year
#
# 🔵Powered by V3V Ventures
# Fake News: False
#
# Message: China’s economy is experiencing its largest financial collapse since its 2002 emergence into the WTO. 10-yr Chinese govt bonds now yield 1.75% and 30-yr bonds are also below 2%. Banks are insolvent and leverage is 350% of ‘reported’ GDP. The first 14 trillion RMB fill a hole.
#
# 🔵Powered by V3V Ventures
# Fake News: False
#
# Message: 🚨 ECB’s Rehn Sees Direction Clear on Rates as Inflation Stabilizes
#
# Olli Rehn, a member of the European Central Bank's Governing Council, indicated that interest rates are expected to decline as inflation stabilizes around the 2% target. He emphasized that the direction of monetary policy is now clear, but the pace and extent of rate cuts will depend on incoming data and thorough analysis during each meeting. Rehn also expressed concerns regarding potential risks from U.S. trade policies.
#
# 🔵Powered by V3V Ventures
# Fake News: False
#
# Message: 🔵Powered by V3V Ventures
# Fake News: False
#
# Message: U.S. Dollar is now used in 49.1% of global payments, the highest level in more than 12 years
#
# 🔵Powered by V3V Ventures
# Fake News: False
#
# Message: Japanese Stocks $EWJ formed a Death Cross for the first time since December 2021. The last one saw stocks enter a bear market with a plunge of more than 30%.
#
# 🔵Powered by V3V Ventures
# Fake News: False
#
# Message: President-elect Trump says Elon Musk's Department of Government Efficiency (DOGE) will eliminate billions in waste and fraud, potentially saving $2 trillion.
#
# 🔵Powered by V3V Ventures
# Fake News: False
#
# Message: The market is convinced a soft landing is coming:
#
# The S&P 500 has risen 9% since the Fed began cutting interest rates in September.
#
# In previous rate cut cycles where a recession was avoided, the S&P 500 gained ~3% on average at this point of the cycle.
#
# On the other hand, when the US economy entered a recession, the index was down ~3%.
#
# In other words, the market is now significantly stronger than it was during previous periods when a soft landing was achieved.
#
# 🔵Powered by V3V Ventures
# Fake News: False
#
# Message: JUST IN: MicroStrategy bought another 15,350 $BTC for $1.5 BILLION
#
# 🔵Powered by V3V Ventures
# Fake News: False
#
# Message: BREAKING: Softbank CEO Masa Son is reportedly visiting the US today to announce a $100 billion investment with President- elect Trump, per CNBC.
#
# The investment will be focused around building out AI and aims to create 100,000 jobs in the US.
#
# 🔵Powered by V3V Ventures
# Fake News: False
#
# Message: Bashar al-Assad’s central bank airlifted around $250mn in cash to Moscow in a two-year period when the then-Syrian dictator was indebted to the Kremlin for military support and his relatives were secretly buying assets in Russia.
#
# 🔵Powered by V3V Ventures
# Fake News: False
#
# Message: Korean Won is on the verge of falling to its weakest level against the U.S. Dollar since the Global Financial Crisis
#
# 🔵Powered by V3V Ventures
# Fake News: False
#
# Message: China's economy is expected to grow by 5% this year.
#
# 🔵Powered by V3V Ventures
# Fake News: False
#
# Message: JUST IN: $4,000 $ETH
#
# 🔵Powered by V3V Ventures
# Fake News: False
#
# Message: Fewer than 20% of Americans currently earn the annual income required to afford a home 😮
#
# 🔵Powered by V3V Ventures
# Fake News: False
#
# Message: Thailand to study the potential of Bitcoin as legal tender.
#
# Former Thailand Prime Minister says his son, the current PM, "may assign the Ministry of Finance to study whether to accept Bitcoin or not" as legal tender.
#
# 🔵Powered by V3V Ventures
# Fake News: False
#
# Message: Bitcoin reaches new all-time high of $104,000. 📈
#
# 🔵Powered by V3V Ventures
# Fake News: False
#
# Message: The Taliban showcase $7,000,000,000 worth of US military equipment left behind during the Biden administration's withdrawal from Afghanistan.
#
# 🔵Powered by V3V Ventures
# Fake News: False
#
# Message: 🚨 ABC News Pays $15 Million To Settle Donald Trump’s Defamation Suit
#
# ABC News and anchor George Stephanopoulos have settled a lawsuit with Donald Trump, who sued the network over false statements made during an interview. Stephanopoulos incorrectly claimed that a jury found Trump liable for raping E. Jean Carroll; in reality, a jury had found Trump liable for sexual abuse but not for rape. Under the settlement, ABC News will pay $15 million to a future presidential foundation and museum established by Trump, plus $1 million for his attorneys' fees.
#
# As part of the agreement, Stephanopoulos will apologize to Trump, and both parties will avoid court-ordered depositions scheduled for next week. Trump accused ABC News and Stephanopoulos of broadcasting false and harmful statements. A judge had previously declined to dismiss the case, focusing on whether the claims were "substantially true."
#
# Carroll has accused Trump of rape dating back to the mid-1990s, and a New York jury awarded her damages for sexual abuse and defamation. Trump has consistently denied her allegations, calling the verdict part of a "witch hunt."
#
# 🔵Powered by V3V Ventures
# Fake News: False
#
# Message: China aims to start commercializing 6G technology by 2030 and expects that the standard-setting for the technology will be achieved by 2025.
#
# 🔵Powered by V3V Ventures
# Fake News: False
#
# Message: Michael Saylor's Microstrategy now owns over 2% of the entire Bitcoin supply.
#
# 🔵Powered by V3V Ventures
# Fake News: False
#
# Message: Broadcom $AVGO brought in more than $30B of revenue from its Semcinoductor segment over the past year up from $17.3B in 2020
#
# 🔵Powered by V3V Ventures
# Fake News: False
#
# Message: Chinese President Xi Jinping says "BRICS is fundamentally changing the world market."
#
# 🔵Powered by V3V Ventures
# Fake News: False
#
# Message: Microstrategy to join NASDAQ-100 index beginning December 23, 2024.
#
# 🔵Powered by V3V Ventures
# Fake News: False
#
# Message: Russia strikes 10-year deal to supply India with 500,000 barrels of crude oil per day for $13 billion annually
#
# 🔵Powered by V3V Ventures
# Fake News: False
#
# Message: Tesla jumps to another all-time high. $TSLA has now made an ATH in 3 consecutive days, finishing the week strong 💪
#
# 🔵Powered by V3V Ventures
# Fake News: False
#
# Message: MicroStrategy $MSTR added to the Nasdaq 100.  All $QQQ investors are now Bitcoin $BTC investors!
#
# 🔵Powered by V3V Ventures
# Fake News: False
#
# Message: Senator Cynthia Lummis meets with Trump's incoming Treasury Secretary Scott Bessent to discuss a Strategic Bitcoin Reserve.
#
# 🔵Powered by V3V Ventures
# Fake News: False
#
# Message: Billionaire Dan Morehead says Bitcoin is much better than gold.
#
# 🔵Powered by V3V Ventures
# Fake News: False
#
# Message: 📊Broadcom’s AI Boom: Stock Soars on Bold Revenue Forecast
#
# Broadcom (AVGO) surged over 20% on Friday as CEO Hock Tan highlighted a “massive” opportunity in artificial intelligence.
#
# The company expects its custom AI chips to generate $60–$90 billion in revenue over the next three years.
#
# 🔵Powered by V3V Ventures
# Fake News: False
#
# Message: ❗️SEC Pressures Musk Over Twitter Deals
#
# The SEC has demanded Elon Musk settle or face charges over alleged securities fraud linked to his 2022 Twitter share transactions and Tesla stock sales ahead of his Twitter buyout.
#
# 🔵Powered by V3V Ventures
# Fake News: False
#
# Message: Japanese lawmaker pushes for a national Bitcoin reserve, joining global calls to adopt $BTC as a strategic asset.
#
# 🔵Powered by V3V Ventures
# Fake News: False
#
# Message: Texas Lt. Governor Dan Patrick says the state of Texas is prepared to buy up all of the border wall segments the Biden Administration is auctioning for $5 a segment and donate then back to the Trump administration. He has $1 billion to work with.
#
# 🔵Powered by V3V Ventures
# Fake News: False
#
# Message: Bill Ackman describes the upcoming Trump administration as “the most pro-growth, pro-business, pro-American” he has witnessed in his adult life.
#
# 🔵Powered by V3V Ventures
# Fake News: False
#
# Message: JUST IN: 🇺🇸 US President-elect Trump trolls Jim Cramer.
#
# Cramer: Should people buy more stocks?
#
# Trump: "I don't want to get into a situation where they do and we have a dip or something because that can always happen. You know that better than anybody in the world."
#
# 🔵Powered by V3V Ventures
# Fake News: True
#
# Message: JUST IN: 🇺🇸 President-elect Trump on crypto and AI
#
# "We're going to do something great with crypto because we don't want China or anybody else, not just China but others are embracing it, and we want to be the head.
#
# We're going to be ahead of AI, we're going to be way ahead of AI, and we've got to produce tremendous amounts of electricity."
#
# 🔵Powered by V3V Ventures
# Fake News: False
#
# Message: 🇺🇸 Jim Cramer interviews President-elect Trump at the New York Stock Exchange opening.
#
# 🔵Powered by V3V Ventures
# Fake News: False
#
# Message: 🇺🇸 President-elect Trump rings New York Stock Exchange opening bell after being named TIME's 'Person of the Year.'
#
# 🔵Powered by V3V Ventures
# Fake News: False
#
# Message: Meta CEO Mark Zuckerberg donates $1,000,000 to President-elect Trump's inaugural fund.
#
# 🔵Powered by V3V Ventures
# Fake News: False
#
# Message: 📈Tesla $TSLA reaches new all-time high of $420.
#
# 🔵Powered by V3V Ventures
# Fake News: False
#
# Message: 📱 Meta services down worldwide, affecting Facebook, Instagram, and WhatsApp.
#
# 🔵Powered by V3V Ventures
# Fake News: False
#
# Message: ⚠️Elon Musk becomes first person to surpass $400 billion net worth.
#
# 🔵Powered by V3V Ventures
# Fake News: False
#
# Message: ⚠️Fed Rate Cut Likely as Inflation Holds Steady
#
# November's 2.7% CPI rise matched forecasts, with core inflation steady at 3.3%. While shelter costs eased slightly, food and used car prices climbed. Markets now see a 97% chance of a December rate cut.
#
# 🔵Powered by V3V Ventures
# Fake News: False
#
# Message: JUST IN: 🇺🇸 President-elect Trump says anyone investing over $1 billion in the US will receive expedited approvals and permits.
#
# 🔵Powered by V3V Ventures
# Fake News: False
#
# Message: Amazon Is Maintained at Outperform by Mizuho
#
# Amazon Price Target Raised to $260.00/Share From $240.00 by Mizuho
#
# 🔵Powered by V3V Ventures
# Fake News: False
#
# Message: Oracle Is Maintained at Outperform by Mizuho
#
# Oracle Price Target Raised to $210.00/Share From $185.00 by Mizuho
#
# 🔵Powered by V3V Ventures
# Fake News: False
#
# Message: Taiwan Semiconductor Reports November Net Revenue of $8.49 Billion
#
# Taiwan Semiconductor Manufacturing said Tuesday that its net revenue rose to NT$276.06 billion ($8.49 billion) in November, from NT$206.03 billion in the same month last year.
#
# Compared to October, net revenue in November was down by 12.2%, the company said.
#
# Revenue for the January-November period was NT$2.616 trillion, an increase of 31.8% compared to the same period in 2023, the company said.
#
# 🔵Powered by V3V Ventures
# Fake News: False
#
# Message: LCID: Lucid Stock Gains 10% as Investors Ease Concerns Over Trump’s EV Tax Credits
#
# Read the full story here.
#
# 🔵Powered by V3V Ventures
# Fake News: False
#
# Message: NVDA: Nvidia Stock Tumbles 2.5% After China Launches Antitrust Investigation
#
# Read the full story here.
#
# 🔵Powered by V3V Ventures
# Fake News: False
#
# Message: MSTR: MicroStrategy Jams $2.1 Billion Into More Bitcoin But the Stock Falls 6%
#
# Read the full story here.
#
# 🔵Powered by V3V Ventures
# Fake News: False
#
# Message: JUST IN: $122,000,000 liquidated from the cryptocurrency market in the past 60 minutes.
#
# 🔵Powered by V3V Ventures
# Fake News: False
#
# Message: 🖥 OpenAI's Ai Video Generator 'sora' Released For The Public
#
# Sam Altman:
# this is early--think of it like GPT-1 for video
#
# • You can do Text to video, image to video, video to video
#
# • if you have an OpenAI Plus or Pro account, you can generate videos. anyone can view them.
#
# • with an OpenAI Plus account, you get 50 generations/mo
#
# • with a Pro account, you get 500 fast generations (or fewer at high resolution) and unlimited in a slower generation mode.
#
# • available in many countries, but not most of europe and the UK for now.
#
# 🔵Powered by V3V Ventures
# Fake News: False
#
# Message: 📈Tesla Rises Above $400 Per Share For First Time Since Jan. 2022
#
# 🔵Powered by V3V Ventures
# Fake News: False
#
# Message: JUST IN: MicroStrategy buys another 21,550 Bitcoin worth $2.1 billion.
#
# 🔵Powered by V3V Ventures
# Fake News: False
#
# Message: ⚠️Trump: Tariffs & Immigration
#
# Trump admits tariffs could raise prices and vows swift action on immigration, including border security and deportations.
#
# 🔵Powered by V3V Ventures
# Fake News: False
#
# Message: 📈Bitcoin Hits $100K Milestone, Wall Street Eyes $200K
#
# Wall Street analysts predict a doubling of its value, with targets of $200,000 by late 2025, fueled by hopes of crypto-friendly policies under Trump’s administration.
#
# "We expect Bitcoin to emerge as the new-age premier ‘store of value’ asset, replacing gold," says Gautam Chhugani of Bernstein.
#
# As Bitcoin rises, Fundstrat's Sean Farrell predicts it could break $120,000 soon, calling 2024 a year of "structural tailwinds."
#
# 🔵Powered by V3V Ventures
# Fake News: False
#
# Message: ⚠️Trump says he will not try to replace Fed's Powell
#
# "No, I don't think so. I don't see it," Trump said when asked if he would seek to remove Powell, whose term ends in 2026.
#
# Traders are expecting the Fed to cut interest rates at its upcoming Dec. 17-18 policy meeting, after recent data showed the U.S. labor market was continuing to cool.
#
# 🔵Powered by V3V Ventures
# Fake News: False
#
# Message: JUST IN: Amazon shareholders call on its Board to consider investing in Bitcoin.
#
# 🔵Powered by V3V Ventures
# Fake News: False
#
# Message: 📊Why is Disney Plowing Cash Into a Cruise Line Expansion?
#
# Read the full story here.
#
# 🔵Powered by V3V Ventures
# Fake News: False
#
# Message: ❗️Apple sued for failing to curtail child sexual abuse material on iCloud- NYT
#
# 🔵Powered by V3V Ventures
# Fake News: False
#
# Message: Read the full story here.
#
# 🔵Powered by V3V Ventures
# Fake News: False
#
# Message: JUST IN: 🇺🇸 US Treasury compares Bitcoin to digital gold.
#
# The "primary use case for Bitcoin seems to be a store of value aka digital gold."
#
# 🔵Powered by V3V Ventures
# Fake News: False
#
# Message: 📱 Meta's Stock Gains Amid TikTok Troubles
#
# An Appeals Court upheld a law that might force ByteDance to sell TikTok or face a US ban.
#
# If the ban proceeds, TikTok's users and creators could shift to Instagram Reels, boosting Meta's revenue.
#
# Meta’s stock jumped 2% on the news, with potential gains for YouTube Shorts as well.
#
# 🔵Powered by V3V Ventures
# Fake News: False
#
# Message: 📊 Wall Street opens higher after November job growth soars
#
# Wall Street's main indexes opened higher on Friday as traders increased bets on a Federal Reserve rate cut this month after the November payrolls report.
#
# The Dow Jones Industrial Average $DJI rose 58.6 points, or 0.13%, at the open to 44,824.29.
#
# The S&P 500 $SPX rose 6.3 points, or 0.10%, at the open to 6,081.38​, while the Nasdaq Composite $IXIC rose 43.2 points, or 0.22%, to 19,743.959 at the opening bell.
#
# 🔵Powered by V3V Ventures
# Fake News: False
#
# Message: ⚠️ OpenAI Aims to Ditch 'AGI' Provision With Microsoft in Bid to Raise More Funding, FT Says, Citing Sources
# • OpenAI is weighing ditching a provision on artificial general intelligence that currently keeps Microsoft out of its most advanced models, the FT reports, citing sources.
#
# • Removing the provision could unlock billions of dollars of future investments from Microsoft, which would be able to access OpenAI's artificial general intelligence, or AGI when the ChatGPT maker attains it. AGI is defined as a highly autonomous system that outperforms humans at most economically valuable work.
# Microsoft declined to comment to the FT.
#
# • OpenAI declined to comment on the specifics but Bret Taylor, chair of OpenAI's board, said the board "is focused on fulfilling [its] fiduciary obligation by ensuring that the company is well-positioned to continue advancing its mission of ensuring AGI benefits all of humanity.
# 🔵Powered by V3V Ventures
# Fake News: False
#
# Message: 🇬🇧 UK restricts access to Pump․Fun
#
# 🔵Powered by V3V Ventures
# Fake News: False
#
# Message: Traders Now See An 85% Chance Of A Fed Rate Cut In December Vs 67% Before The Jobs Report.
#
# 🔵Powered by V3V Ventures
# Fake News: False
#
# Message: 💰 ETH Hits $4k After 9 Months.
#
# 🔵Powered by V3V Ventures
# Fake News: False
#
# Message: S&P 500 Rises 15.63 Points (0.26%).
#
# 🔵Powered by V3V Ventures
# Fake News: False
#
# Message: JUST IN: 🇺🇸 President-elect Trump says his new crypto Czar David Sacks will "work on legal framework so the crypto industry has the clarity it has been asking for."
#
# 🔵Powered by V3V Ventures
# Fake News: False
#
# Message: Buffett Bets on Kroger Amid Merger Moves
#
# Kroger missed sales expectations and paused stock buybacks to focus on its Albertsons merger, narrowing its 2024 profit forecast.
#
# Warren Buffett’s Berkshire Hathaway recently boosted its stake to 50 million shares, showing confidence despite the hurdles.
#
# 🔵Powered by V3V Ventures
# Fake News: False
#
# Message: 📱 MicroStrategy: Hedge Funds Ride Bitcoin Volatility on Wall Street
#
# On Wall Street, hedge funds are capitalizing on MicroStrategy's volatile stock through convertible bond arbitrage, taking advantage of Michael Saylor's $40 billion Bitcoin holdings.
#
# The company has issued $7 billion in low-interest notes to fund its Bitcoin purchases. This strategy has become a popular play on Wall Street.
#
# 🔵Powered by V3V Ventures
# Fake News: False
#
# Message: JUST IN: $450,000,000 liquidated from the cryptocurrency market in the past 60 minutes.
#
# 🔵Powered by V3V Ventures
# Fake News: False
#
# Message: JUST IN: Over $100,000,000 liquidated from the cryptocurrency market in the past 60 minutes.
#
# 🔵Powered by V3V Ventures
# Fake News: False
#
# Message: 🇺🇸 President-elect Trump congratulates Bitcoin holders on surpassing $100,000
#
# 🔵Powered by V3V Ventures
# Fake News: False
#
# Message: 🇷🇺 Russian President Putin says "who can ban Bitcoin?"
#
# "Nobody"
#
# 🔵Powered by V3V Ventures
# Fake News: False
#
# Message: JUST IN: Michael Saylor's MicroStrategy Bitcoin investment surpasses $18 billion profit.
#
# 🔵Powered by V3V Ventures
# Fake News: False
#
# Message: JUST IN: $102,850 Bitcoin
# Fake News: False
#
# Message: Tech Stocks Soar as Fed Hints at Rate Cut
#
# Tech giants like Amazon, Apple, and Nvidia powered the Nasdaq up 1% on Wednesday. Investors cheered Fed Chair Powell’s signal that a December rate cut is likely.
#
# 🔵Powered by V3V Ventures
# Fake News: False
#
# Message: Tesla Lawsuit: Lawyers Awarded $345M, Musk Loses
#
# Lawyers seeking $5.6 billion for challenging Elon Musk’s $55.8 billion pay package were awarded $345 million. Musk’s bid to reinstate the pay was denied, a win for Tesla shareholders.
#
# 🔵Powered by V3V Ventures
# Fake News: False
#
# Message: JUST IN: 🇺🇸 FED Chair Jerome Powell says Bitcoin "is a competitor with Gold, not the US Dollar."
#
# 🔵Powered by V3V Ventures
# Fake News: False
#
# Message: ❗️UnitedHealth CEO Shot in Midtown
#
# Brian Thompson, CEO of UnitedHealthcare, the largest private health insurer in the U.S., was fatally shot in midtown Manhattan on Wednesday morning.
#
# The company canceled its investor day following the incident.
#
# 🔵Powered by V3V Ventures
# Fake News: False
#
# Message: BREAKING: 🇺🇸 President-elect Trump officially selects pro-crypto Paul Atkins to replace Gary Gensler as SEC Chair.
#
# 🔵Powered by V3V Ventures
# Fake News: False
#
# Message: JUST IN: Citadel CEO Ken Griffin says he regrets not buying crypto a few years ago.
#
# 🔵Powered by V3V Ventures
# Fake News: False
#
# Message: JUST IN: 🇷🇺 Russia's President Putin says Bitcoin & digital assets will continue to develop.
#
# 🔵Powered by V3V Ventures
# Fake News: False
#
# Message: JUST IN: Virgin Voyages becomes the first cruise line to accept Bitcoin for payments.
#
# 🔵Powered by V3V Ventures
# Fake News: False
#
# Message: JUST IN: $443 million liquidated from the cryptocurrency market in the past 12 hours.
#
# 🔵Powered by V3V Ventures
# Fake News: False
#
# Message: 💎BlackRock Bets Big on Private Credit
#
# BlackRock is acquiring HPS Investment Partners for $12 billion, boosting its private credit assets to $220 billion. The deal, set to close by mid-2025, capitalizes on the booming private credit market.
#
# 🔵Powered by V3V Ventures
# Fake News: False
#
# Message: 📉Won Plunges After Emergency Alert
#
# South Korea’s won on Tuesday fell sharply against the U.S. dollar shortly after President Yoon Suk Yeol declared a state of emergency.
#
# The U.S. dollar was last seen trading up 1.9% against the won, which notched a fresh two-year low on the news.
#
# 🔵Powered by V3V Ventures
# Fake News: False
#
# Message: ⚠️Market Shake-Up: US Steel & Tesla Hit Headlines
#
# US Steel shares dropped as Trump vowed to block its sale to Japan's Nippon Steel. Tesla plans to appeal a court’s rejection of Elon Musk’s $56 billion pay package.
#
# 🔵Powered by V3V Ventures
# Fake News: False
#
# Message: 🔵Powered by V3V Ventures
# Fake News: False
#
# Message: 📊S&P 500 to Hit 6,666 in 2025, BofA Predicts
#
# Bank of America forecasts the S&P 500 will reach 6,666 by 2025, driven by 2.4% GDP growth and a shift to large-cap value stocks. The rally is expected to broaden beyond Big Tech to other sectors like financials and materials.
#
# 🔵Powered by V3V Ventures
# Fake News: False
#
# Message: JUST IN: Coinbase now allows users to purchase cryptocurrency with Apple Pay.
#
# 🔵Powered by V3V Ventures
# Fake News: False
#
# Message: 📌📈Intel CEO Pat Gelsinger Retires, Stock Rises
#
# Pat Gelsinger retired as Intel CEO on Dec. 1 after over three years of turnaround efforts. The board, losing confidence, made the decision privately, notifying leadership only a day before.
# Intel shares jumped 3% on the news.
#
# 🔵Powered by V3V Ventures
# Fake News: False

# %%
import pickle

# Specify the path to your .pkl file
file_path = 'fakenewsmodel.pkl' # Replace with the actual path

try:
    # Open and load the .pkl file
    with open(file_path, 'rb') as file:
        data = pickle.load(file)

    # Now you can work with the loaded data
    print(data)

except pickle.UnpicklingError as e:
    print(f"Error loading the pickle file: {e}")
    print("Please check if the file is complete and not corrupted.")

except FileNotFoundError as e:
    print(f"Error: File not found: {e}")
    print("Please ensure the file exists at the specified path.")
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator DecisionTreeClassifier from version 1.5.2 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# Error loading the pickle file: pickle data was truncated
# Please check if the file is complete and not corrupted.
